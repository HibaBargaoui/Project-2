# %% [markdown]
# <a href="https://colab.research.google.com/github/HibaBargaoui/Project-2/blob/main/Project_2_Part_1_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mount drive**

# %%
from google.colab import drive
drive.mount('/content/MyDrive/')
# Out:
# Mounted at /content/MyDrive/

# %% [markdown]
# **Import library**

# %%
import pandas as pd

# %% [markdown]
# ## *First choice:* Supply Chain Optimization for a FMCG Company

# %%
# Load Data
df1 = pd.read_csv('/content/MyDrive/MyDrive/Coding Dojo/Datasets/FMCG_data.csv')
df1.head()
# Out:
#   Ware_house_ID WH_Manager_ID Location_type WH_capacity_size   zone  \
# 0     WH_100000     EID_50000         Urban            Small   West
# 1     WH_100001     EID_50001         Rural            Large  North
# 2     WH_100002     EID_50002         Rural              Mid  South
# 3     WH_100003     EID_50003         Rural              Mid  North
# 4     WH_100004     EID_50004         Rural            Large  North
#
#   WH_regional_zone  num_refill_req_l3m  transport_issue_l1y  \
# 0           Zone 6                   3                    1
# 1           Zone 5                   0                    0
# 2           Zone 2                   1                    0
# 3           Zone 3                   7                    4
# 4           Zone 5                   3                    1
#
#    Competitor_in_mkt  retail_shop_num  ... electric_supply  dist_from_hub  \
# 0                  2             4651  ...               1             91
# ...

# %% [markdown]
# **Q & A:**
# 1. Source of data
#
# https://www.kaggle.com/datasets/suraj9727/supply-chain-optimization-for-a-fmcg-company
#
# 2. Brief description of data
#
# This dataset presents informations related to the instant noodles business of a leading FMCG company.
#
# 3. What is the target?
#
# We can predict the 'product_wg_ton' column.
#
# 4. What does one row represent? (A person? A business? An event? A product?)
#
# A lot of information regarding the warehouse ID, location and zone, the number of transportation issues, the storage issue, etc
#
# 5. Is this a classification or regression problem?
#
# This is a regression problem.
#
# 6. How many features does the data have?
#
# The data have 24 features.
#
# 7. How many rows are in the dataset?
#
# There are 25000 rows in the dataset.
#
# 8. What, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?
#
# There are some missing values.

# %% [markdown]
# ## Second choice: Stock Market contains historical Data of Top 10 Companies

# %%
df2 = pd.read_csv('/content/MyDrive/MyDrive/Coding Dojo/Datasets/data_stock.csv')
df2.head()
# Out:
#   Company        Date Close/Last    Volume     Open       High      Low
# 0    AAPL  07/17/2023    $193.99  50520160  $191.90    $194.32  $191.81
# 1    AAPL  07/14/2023    $190.69  41616240  $190.23  $191.1799  $189.63
# 2    AAPL  07/13/2023    $190.54  41342340  $190.50    $191.19  $189.78
# 3    AAPL  07-12-2023    $189.77  60750250  $189.68    $191.70  $188.47
# 4    AAPL  07-11-2023    $188.08  46638120  $189.16    $189.30  $186.60

# %% [markdown]
# **Q & A:**
# 1. Source of data
#
# https://www.kaggle.com/datasets/khushipitroda/stock-market-historical-data-of-top-10-companies
#
# 2. Brief description of data
#
# This dataset contains the stock market data for a specific company on a given date.
#
# 3. What is the target?
#
# We can predict whether a stock will rise or fall on the next trading day.
#
# 4. What does one row represent? (A person? A business? An event? A product?)
#
# The stock prices and trading volumes for each company (Apple, Starbucks, Microsoft, etc) on a given date.
#
#
# 5. Is this a classification or regression problem?
#
# This is a binary classification problem.
#
# 6. How many features does the data have?
#
# The data have 7 features.
#
# 7. How many rows are in the dataset?
#
# There are 25160 rows in the dataset.
#
# 8. What, if any, challenges do you foresee in cleaning, exploring, or modeling this dataset?
#
# Creating the target variable, which involves comparing the closing price of a stock on the current trading day with the closing price on the next trading day, can be a bit challenging.
